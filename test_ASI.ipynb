# %%
# !git clone https://github.com/darniton/ASI.git
# Out:
# Cloning into 'ASI'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 158 (delta 11), reused 40 (delta 11), pack-reused 118
# Receiving objects: 100% (158/158), 265.05 MiB | 32.72 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Updating files: 100% (64/64), done.

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# ...
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# ...
#   Using cached tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
# ...
#   Using cached tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
# ...

# %%
# %cd ASI/
# Out:
# /content/ASI

# %%
# %matplotlib inline

import sys
sys.path.append("../../")

from train_model import train

from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot, PredictionError

import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 100
rcParams['font.size'] = 8
rcParams['font.family'] = 'sans-serif'
rcParams['axes.facecolor'] = '#ffffff'
rcParams['lines.linewidth'] = 2.0

# %%
hyperparameter={
"num_nearest":60,
"sigma":2,
"learning_rate":0.001,
"batch_size":250,
"num_neuron":60,
"num_layers":3,
"size_embedded":50,
"num_nearest_geo":45,
"num_nearest_eucli":45,
"id_dataset":'kc',
"epochs":50,
"optimier":'adam',
"validation_split":0.1,
"label":'asi_kc',
"early_stopping": False,
"graph_label":'matrix',
"num_image_features": 512,
}

# %%
spatial = train(**hyperparameter)

# %%
# !pwd
import numpy as np
sequence = ''
data = np.load('/content/ASI/datasets/kc/data.npz', allow_pickle=True)

# original data
X_train = data['X_train']
print(X_train[0])
# Out:
# /content/ASI
# [ 4.76889e+01 -1.22342e+02  2.00000e+00  1.75000e+00  1.99000e+03
#   4.00000e+03  1.00000e+00  0.00000e+00  0.00000e+00  5.00000e+00
#   7.00000e+00  1.09000e+03  9.00000e+02  1.95200e+03  0.00000e+00
#   9.81030e+04  1.27000e+03  5.70000e+03]

# %%
dataset,\
result,\
fit,\
embedded_train,\
embedded_test,\
predict_regression_train,\
predict_regression_test = spatial()
# Out:
# Epoch 1/50
# 57/63 [==========================>...] - ETA: 0s - loss: 4.4735 - root_mean_squared_error: 6.2235
# Epoch 1: val_loss improved from inf to 0.92102, saving model to /content/ASI/output/models/kc/asi_kc_weights.hdf5
# 63/63 [==============================] - 2s 11ms/step - loss: 4.1817 - root_mean_squared_error: 5.9707 - val_loss: 0.9210 - val_root_mean_squared_error: 1.2417
# Epoch 2/50
# 56/63 [=========================>....] - ETA: 0s - loss: 0.6534 - root_mean_squared_error: 0.9160
# Epoch 2: val_loss improved from 0.92102 to 0.41652, saving model to /content/ASI/output/models/kc/asi_kc_weights.hdf5
# 63/63 [==============================] - 0s 7ms/step - loss: 0.6299 - root_mean_squared_error: 0.8864 - val_loss: 0.4165 - val_root_mean_squared_error: 0.5476
# Epoch 3/50
# 54/63 [========================>.....] - ETA: 0s - loss: 0.3172 - root_mean_squared_error: 0.4300
# ...

# %%
# !gdown https://drive.google.com/uc?id=1xjfRiuruqoQPIzDBmEE_C3jtEPJexJlf
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xjfRiuruqoQPIzDBmEE_C3jtEPJexJlf
# From (redirected): https://drive.google.com/uc?id=1xjfRiuruqoQPIzDBmEE_C3jtEPJexJlf&confirm=t&uuid=db23925c-d29a-45cd-b5a7-587b05e7f914
# To: /content/map_images_KC.zip
# 100% 7.43G/7.43G [01:31<00:00, 81.3MB/s]

# %%
# !unzip map_images_KC.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: map_images/img5499.png
#   inflating: map_images/img55.png
#   inflating: map_images/img550.png
#   inflating: map_images/img5500.png
#   inflating: map_images/img5501.png
#   inflating: map_images/img5502.png
#   inflating: map_images/img5503.png
#   inflating: map_images/img5504.png
#   inflating: map_images/img5505.png
#   inflating: map_images/img5506.png
#   inflating: map_images/img5507.png
#   inflating: map_images/img5508.png
#   inflating: map_images/img5509.png
#   inflating: map_images/img551.png
#   inflating: map_images/img5510.png
#   inflating: map_images/img5511.png
#   inflating: map_images/img5512.png
#   inflating: map_images/img5513.png
#   inflating: map_images/img5514.png
#   inflating: map_images/img5515.png
#   inflating: map_images/img5516.png
#   inflating: map_images/img5517.png
#   inflating: map_images/img5518.png
#   inflating: map_images/img5519.png
#   inflating: map_images/img552.png
# ...

# %%
! ls -l map_images/*.png | wc -l
# Out:
# 21608
